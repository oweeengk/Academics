# %% [markdown]
# # CMSC 173 Machine Learning 2022
# > by Moh. Al-Fadhel D. Cali 2019-55019
#
# ## Assignment 1 🧪
#
# Since data cleaning is crucial before using any machine algorithm, kindly include a link to your Jupyter notebook that displays solutions and results for the following issues on a dataset:
#
# - Missing values
# - Outliers
# - Duplicate records
# - Data type issues
# - Others (kindly include other issues regarding the dataset that you are using)
#
# ## Dataset 📓
# **The Iris Species is the Iris Plant Database**, which has three classes with a total of 50 instances, each class referring to a different kind of iris plant. Two classes cannot be linearly separated from one another, although one class can be linearly separated from the other two. This dataset's columns contain Id, Sepallength, PetalLength, and others.
# > **10 Datasets for Data Cleaning Practice for Beginners** see https://analyticsindiamag.com/10-datasets-for-data-cleaning-practice-for-beginners/
#
# ## Visualization of data ✨
#
# Below is the current visualization of the downloaded dataset **iris.csv** from the website. Data taken from https://www.kaggle.com/datasets/uciml/iris?resource=download

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('Iris.csv','r') as csvfile:
	plots = csv.reader(csvfile, delimiter = ',')
	next(plots)
	for row in plots:
		x.append(row[1])
		y.append((row[0]))

plt.bar(y, x, color = 'g', width = 0.82)
plt.xlabel('Species')
plt.ylabel('Sepal Length (cm)')
plt.title('Sepal Length (cm) of ID')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# > **Bar graphs** are more suitable to these large data, but for clarity purposes, scatter plots can be clearer due to lesser spacing in Jupyter Notebook

# %%
import pandas as pd
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = [10.00, 3.50]
plt.rcParams["figure.autolayout"] = True
columns = ["Id", "SepalLengthCm"]
df = pd.read_csv("iris.csv", usecols=columns)
print("Contents in csv file:\n", df)
plt.scatter(df.Id, df.SepalLengthCm)
plt.title('Sepal Length (cm) x ID')
plt.show()
# Out:
# Contents in csv file:
#        Id  SepalLengthCm
# 0      1            5.1
# 1      2            4.9
# 2      3            4.7
# 3      4            4.6
# 4      5            5.0
# ..   ...            ...
# 145  146            6.7
# 146  147            6.3
# 147  148            6.5
# 148  149            6.2
# 149  150            5.9
#
# [150 rows x 2 columns]
# C:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import pandas as pd
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = [10.00, 3.50]
plt.rcParams["figure.autolayout"] = True
columns = ["Id", "SepalWidthCm"]
df = pd.read_csv("iris.csv", usecols=columns)
print("Contents in csv file:\n", df)
plt.scatter(df.Id, df.SepalWidthCm)
plt.title('Sepal Width (cm) x ID')
plt.show()
# Out:
# Contents in csv file:
#        Id  SepalWidthCm
# 0      1           3.5
# 1      2           3.0
# 2      3           3.2
# 3      4           3.1
# 4      5           3.6
# ..   ...           ...
# 145  146           3.0
# 146  147           2.5
# 147  148           3.0
# 148  149           3.4
# 149  150           3.0
#
# [150 rows x 2 columns]
# C:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import pandas as pd
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = [10.00, 3.50]
plt.rcParams["figure.autolayout"] = True
columns = ["Id", "PetalLengthCm"]
df = pd.read_csv("iris.csv", usecols=columns)
print("Contents in csv file:\n", df)
plt.scatter(df.Id, df.PetalLengthCm)
plt.title('Petal Length (cm) x ID')
plt.show()
# Out:
# Contents in csv file:
#        Id  PetalLengthCm
# 0      1            1.4
# 1      2            1.4
# 2      3            1.3
# 3      4            1.5
# 4      5            1.4
# ..   ...            ...
# 145  146            5.2
# 146  147            5.0
# 147  148            5.2
# 148  149            5.4
# 149  150            5.1
#
# [150 rows x 2 columns]
# C:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import pandas as pd
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = [10.00, 3.50]
plt.rcParams["figure.autolayout"] = True
columns = ["Id", "PetalWidthCm"]
df = pd.read_csv("iris.csv", usecols=columns)
print("Contents in csv file:\n", df)
plt.scatter(df.Id, df.PetalWidthCm)
plt.title('Petal Width (cm) x ID')
plt.show()
# Out:
# Contents in csv file:
#        Id  PetalWidthCm
# 0      1           0.2
# 1      2           0.2
# 2      3           0.2
# 3      4           0.2
# 4      5           0.2
# ..   ...           ...
# 145  146           2.3
# 146  147           1.9
# 147  148           2.0
# 148  149           2.3
# 149  150           1.8
#
# [150 rows x 2 columns]
# C:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import pandas as pd
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = [10.00, 3.50]
plt.rcParams["figure.autolayout"] = True
columns = ["Id", "Species"]
df = pd.read_csv("iris.csv", usecols=columns)
print("Contents in csv file:\n", df)
plt.scatter(df.Id, df.Species)
plt.title('Species x ID')
plt.show()
# Out:
# Contents in csv file:
#        Id         Species
# 0      1     Iris-setosa
# 1      2     Iris-setosa
# 2      3     Iris-setosa
# 3      4     Iris-setosa
# 4      5     Iris-setosa
# ..   ...             ...
# 145  146  Iris-virginica
# 146  147  Iris-virginica
# 147  148  Iris-virginica
# 148  149  Iris-virginica
# 149  150  Iris-virginica
#
# [150 rows x 2 columns]
# C:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## Data Cleaning ✨
#
# **Data type issues**
#
#     Let's look for data type issues and fix them if ever

# %%
import pandas as pd
df = pd.read_csv('iris.csv', nrows=2)
for dtype in df.dtypes.iteritems():
    print(dtype)
# Out:
# ('Id', dtype('int64'))
# ('SepalLengthCm', dtype('float64'))
# ('SepalWidthCm', dtype('float64'))
# ('PetalLengthCm', dtype('float64'))
# ('PetalWidthCm', dtype('float64'))
# ('Species', dtype('O'))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9256\2134926012.py:3: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for dtype in df.dtypes.iteritems():

# %% [markdown]
# There seems to be no data type issues present. The data is consistently written out.
#
#
#
# **Missing values**
#
#     Let's look for possible missing values and fix them if ever

# %%
df.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# There seems to be no missing values in each of the columns (Id, SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, and Species)
#
#
#
# **Duplicate records**
#
#     Let's look for possible duplicate records and fix them if ever

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There seems to be no duplicated value in the columns.
#
#
#
# **Outliers**
#
#     Let's look for possible outliers and fix them if ever

# %%
import numpy
numeric_col = ['SepalLengthCm','SepalWidthCm','PetalLengthCm', 'PetalWidthCm']
categorical_col = ['Species']
df.boxplot(numeric_col)
# Out:
# C:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# There seems to be outliers only in SepalWidthCm.
#
# Using IQR, we can follow the below approach to replace the outliers with a NULL value:
#
# - Calculate the first and third quartile (Q1 and Q3).
# - Further, evaluate the interquartile range, IQR = Q3-Q1.
# - Estimate the lower bound, the lower bound = Q1*1.5
# - Estimate the upper bound, upper bound = Q3*1.5
# - Replace the data points that lie outside of the lower and the upper bound with a NULL value.

# %%
for x in ['SepalWidthCm']:
    q75,q25 = numpy.percentile(df.loc[:,x],[75,25])
    intr_qr = q75-q25
 
    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
 
    df.loc[df[x] < min,x] = numpy.nan
    df.loc[df[x] > max,x] = numpy.nan

# %% [markdown]
# Having replaced the outliers with nan, let us now check the sum of null values or missing values using the below code:

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df = df.dropna(axis = 0)
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# Thus, all outliers have been treated for better presentation.
